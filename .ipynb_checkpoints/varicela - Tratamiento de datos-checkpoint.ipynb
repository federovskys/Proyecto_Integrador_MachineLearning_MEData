# %% [markdown]
# # Carga de tablas

# %%
import pandas as pd

import numpy as np


datos = pd.read_excel('varicela.xlsx')#se carga la base de datos

#Transformación de las variables categóricas

df = pd.DataFrame(data=datos) #Se crea un dataframe con los datos

# %% [markdown]
# # Códigos transformación de datos

# %%
from sklearn import preprocessing
from collections import defaultdict

df1 = df
d = defaultdict(preprocessing.LabelEncoder)


def SoloInt(X): #Método para saber si toda la columna es de int
    #for j in range (len(X)):
    if not(X.dtype == 'int64'):
            return False
    return True


labels = []
for c in datos:
    labels.append(c)#Contiene todas las características de la base de datos


for i in range (len(labels)):
    if not (SoloInt(df[labels[i]])):
        # Codificando la variable
        df1[labels[i]] = df1[labels[i]].astype(str)
        df1[labels[i]] = d[labels[i]].fit_transform(df[labels[i]])


datosCodificados = df1

for i in range (len(labels)):
    if (labels[i] in d):
        if isinstance(d[labels[i]].classes_[0], str):
            index = np.where(d[labels[i]].classes_ == 'Nulo')[0]
            datosCodificados[labels[i]].replace(index, np.nan , inplace = True)
    else:
        datosCodificados[labels[i]].replace(-1, np.nan , inplace = True)

        
datosCodificados
# Out:
#         ano  semana  edad_  uni_med_  sexo_  nombre_barrio  comuna  tipo_ss_  \
# 0      2008      18    8.0       1.0    1.0            NaN     NaN       0.0
# 1      2008      18   34.0       1.0    1.0          285.0    10.0       0.0
# 2      2008      18   23.0       1.0    1.0          203.0     3.0       0.0
# 3      2008      19    6.0       1.0    1.0          190.0     5.0       0.0
# 4      2008      19    7.0       1.0    1.0          273.0     9.0       0.0
# 5      2008      19    5.0       1.0    1.0          159.0    17.0       0.0
# 6      2008      19   32.0       1.0    0.0          361.0     5.0       0.0
# 7      2008      19    1.0       1.0    1.0          150.0    19.0       0.0
# 8      2008      19   19.0       1.0    0.0           93.0    19.0       0.0
# 9      2008      18   12.0       1.0    1.0          307.0    10.0       0.0
# 10     2008      18   31.0       1.0    0.0           27.0    19.0       0.0
# 11     2008      18    3.0       1.0    0.0           64.0     1.0       3.0
# 12     2008      19    8.0       1.0    1.0          266.0     1.0       0.0
# 13     2008      19   10.0       1.0    1.0          139.0    17.0       0.0
# 14     2008      19    2.0       1.0    1.0          150.0    19.0       0.0
# 15     2008      19    7.0       1.0    0.0          368.0     8.0       0.0
# 16     2008      19    6.0       1.0    1.0          414.0     6.0       0.0
# 17     2008      19    2.0       1.0    1.0          176.0    11.0       0.0
# 18     2008      19   11.0       1.0    0.0          172.0    11.0       0.0
# 19     2008      19   16.0       1.0    1.0          172.0    11.0       0.0
# 20     2008      19    3.0       1.0    0.0          187.0     4.0       0.0
# 21     2008      19   33.0       1.0    1.0           19.0     4.0       0.0
# 22     2008      19   29.0       1.0    1.0          226.0     4.0       0.0
# 23     2008      20    5.0       1.0    0.0          244.0     1.0       0.0
# 24     2008      19    6.0       1.0    0.0          318.0    13.0       0.0
# 25     2008      20   11.0       1.0    0.0          175.0    19.0       0.0
# 26     2008      20   33.0       1.0    0.0          175.0    19.0       0.0
# 27     2008      20   20.0       1.0    1.0          413.0    11.0       0.0
# 28     2008      20   22.0       1.0    1.0            NaN     NaN       0.0
# 29     2008      20    2.0       1.0    0.0           11.0    15.0       0.0
# ...     ...     ...    ...       ...    ...            ...     ...       ...
# 52813  2017      39    1.0       1.0    1.0          285.0    33.0       0.0
# 52814  2017      39    1.0       1.0    0.0          381.0    27.0       0.0
# 52815  2017      39    5.0       1.0    0.0          198.0    32.0       0.0
# 52816  2017      39    7.0       1.0    1.0           78.0    25.0       0.0
# 52817  2017      39    5.0       1.0    0.0          220.0    29.0       0.0
# 52818  2017      39    6.0       1.0    0.0          173.0    39.0       0.0
# 52819  2017      39    5.0       1.0    1.0           49.0    26.0       0.0
# 52820  2017      39    7.0       1.0    1.0          218.0    41.0       0.0
# 52821  2017      39    2.0       1.0    1.0          466.0    21.0       6.0
# 52822  2017      39   15.0       1.0    1.0          318.0    37.0       0.0
# 52823  2017      39   16.0       1.0    1.0          388.0    30.0       0.0
# 52824  2017      39   14.0       1.0    1.0          208.0    29.0       0.0
# 52825  2017      39   16.0       1.0    0.0          239.0    32.0       0.0
# 52826  2017      39    8.0       1.0    1.0          458.0    36.0       0.0
# 52827  2017      39    7.0       1.0    1.0          338.0    44.0       0.0
# 52828  2017      39    9.0       1.0    0.0           11.0    39.0       0.0
# 52829  2017      39   10.0       1.0    1.0           70.0    35.0       0.0
# 52830  2017      39   10.0       1.0    1.0          116.0    37.0       6.0
# 52831  2017      39   13.0       1.0    0.0           38.0    23.0       0.0
# 52832  2017      39    9.0       1.0    1.0          338.0    44.0       0.0
# 52833  2017      39   12.0       1.0    1.0          116.0    37.0       0.0
# 52834  2017      39    9.0       1.0    1.0          288.0    31.0       0.0
# 52835  2017      39   11.0       1.0    0.0           10.0    35.0       0.0
# 52836  2017      39   13.0       1.0    0.0           68.0    23.0       0.0
# 52837  2017      39    9.0       1.0    1.0          236.0    35.0       5.0
# 52838  2017      39    9.0       1.0    0.0           85.0    32.0       0.0
# 52839  2017      39   12.0       1.0    1.0          374.0    32.0       0.0
# 52840  2017      39    8.0       1.0    1.0          368.0    31.0       0.0
# 52841  2017      39   17.0       1.0    1.0           74.0    21.0       0.0
# 52842  2017      39   17.0       1.0    0.0           91.0    35.0       0.0
#
#        cod_ase_  fec_con_  ini_sin_  tip_cas_  pac_hos_
# 0          94.0     121.0     162.0         4         2
# 1          82.0     122.0     162.0         4         2
# 2          82.0     121.0     158.0         4         2
# 3          82.0     126.0     165.0         4         2
# 4          82.0     122.0     164.0         4         2
# 5          88.0     122.0     163.0         4         2
# 6          65.0     125.0     160.0         4         1
# 7          88.0     121.0     161.0         4         2
# 8          88.0     121.0     156.0         4         2
# 9          28.0     126.0     166.0         4         2
# 10         88.0     122.0     161.0         4         2
# 11          NaN     125.0     164.0         4         2
# 12        158.0     122.0     163.0         4         2
# 13         94.0     128.0     167.0         4         2
# 14         94.0     129.0     171.0         4         2
# 15         76.0     130.0     170.0         4         2
# 16         76.0     130.0     171.0         4         2
# 17         82.0     128.0     167.0         4         2
# 18         82.0     125.0     165.0         4         2
# 19         82.0     125.0     165.0         4         2
# 20         82.0     132.0     174.0         4         2
# 21         82.0     128.0     166.0         5         2
# 22         82.0     131.0     166.0         4         2
# 23        158.0     131.0     173.0         4         2
# 24         94.0      79.0     118.0         4         2
# 25         96.0     129.0     169.0         4         2
# 26         96.0     130.0     173.0         4         2
# 27         94.0     131.0     172.0         4         2
# 28         96.0     131.0     173.0         4         2
# 29          NaN     121.0     159.0         4         2
# ...         ...       ...       ...       ...       ...
# 52813      78.0    3562.0    3604.0         4         2
# 52814      82.0    3555.0    3599.0         4         2
# 52815      75.0    3559.0    3599.0         4         2
# 52816      75.0    3559.0    3601.0         4         2
# 52817      90.0    3555.0    3599.0         4         2
# 52818      82.0    3556.0    3600.0         4         2
# 52819      82.0    3557.0    3598.0         4         2
# 52820      76.0    3554.0    3598.0         4         2
# 52821     128.0    3557.0    3598.0         4         2
# 52822      75.0    3561.0    3602.0         4         2
# 52823     103.0    3591.0    3602.0         4         2
# 52824     108.0    3562.0    3604.0         4         2
# 52825      82.0    3557.0    3600.0         4         2
# 52826      82.0    3560.0    3603.0         4         2
# 52827      82.0    3562.0    3603.0         4         2
# 52828     119.0    3562.0    3600.0         4         2
# 52829      82.0    3560.0    3599.0         4         2
# 52830     128.0    3558.0    3602.0         4         2
# 52831      82.0    3558.0    3599.0         4         2
# 52832      88.0    3555.0    3598.0         4         2
# 52833      82.0    3558.0    3600.0         4         2
# 52834     108.0    3557.0    3599.0         4         2
# 52835      82.0    3557.0    3600.0         4         2
# 52836     108.0    3566.0    3600.0         4         2
# 52837     155.0    3560.0    3603.0         4         2
# 52838      82.0    3556.0    3599.0         4         2
# 52839      88.0    3559.0    3603.0         4         2
# 52840      82.0    3561.0    3602.0         4         2
# 52841     108.0    3557.0    3598.0         4         2
# 52842      78.0    3558.0    3600.0         4         2
#
# [52843 rows x 13 columns]

# %% [markdown]
# # Empieza tratamiento de datos - Llenado de datos

# %%
from sklearn.impute import SimpleImputer

#Llenar datos vacíos y pasar de DataFrame a Matriz
estrategia = SimpleImputer(strategy = 'most_frequent') #Se rellenan los datos faltantes por el método de el dato más frecuente
datosNuevos = estrategia.fit_transform(datosCodificados)

  
labels = []
for c in df:
    labels.append(c)


df_completo = pd.DataFrame(data=datosNuevos, columns=labels)#Creamos un nuevo df para el manejo de outliers

# %% [markdown]
# # Manejo de outliers

# %%
from pandas.api.types import is_numeric_dtype

def remove_outlier(df):
    low = .01
    high = .99
    quant_df = df.quantile([low, high])
    for name in list(df.columns):
        if is_numeric_dtype(df[name]):
            df = df[(df[name] >= quant_df.loc[low, name]) & (df[name] <= quant_df.loc[high, name])]
    return df



df_sinOutLiers = remove_outlier(df_completo)
datosNuevos = df_sinOutLiers.values
df_sinOutLiers
# Out:
#           ano  semana  edad_  uni_med_  sexo_  nombre_barrio  comuna  \
# 0      2008.0    18.0    8.0       1.0    1.0          285.0    15.0
# 1      2008.0    18.0   34.0       1.0    1.0          285.0    10.0
# 2      2008.0    18.0   23.0       1.0    1.0          203.0     3.0
# 3      2008.0    19.0    6.0       1.0    1.0          190.0     5.0
# 4      2008.0    19.0    7.0       1.0    1.0          273.0     9.0
# 5      2008.0    19.0    5.0       1.0    1.0          159.0    17.0
# 6      2008.0    19.0   32.0       1.0    0.0          361.0     5.0
# 7      2008.0    19.0    1.0       1.0    1.0          150.0    19.0
# 8      2008.0    19.0   19.0       1.0    0.0           93.0    19.0
# 9      2008.0    18.0   12.0       1.0    1.0          307.0    10.0
# 10     2008.0    18.0   31.0       1.0    0.0           27.0    19.0
# 11     2008.0    18.0    3.0       1.0    0.0           64.0     1.0
# 12     2008.0    19.0    8.0       1.0    1.0          266.0     1.0
# 13     2008.0    19.0   10.0       1.0    1.0          139.0    17.0
# 14     2008.0    19.0    2.0       1.0    1.0          150.0    19.0
# 15     2008.0    19.0    7.0       1.0    0.0          368.0     8.0
# 16     2008.0    19.0    6.0       1.0    1.0          414.0     6.0
# 17     2008.0    19.0    2.0       1.0    1.0          176.0    11.0
# 18     2008.0    19.0   11.0       1.0    0.0          172.0    11.0
# 19     2008.0    19.0   16.0       1.0    1.0          172.0    11.0
# 20     2008.0    19.0    3.0       1.0    0.0          187.0     4.0
# 22     2008.0    19.0   29.0       1.0    1.0          226.0     4.0
# 23     2008.0    20.0    5.0       1.0    0.0          244.0     1.0
# 24     2008.0    19.0    6.0       1.0    0.0          318.0    13.0
# 25     2008.0    20.0   11.0       1.0    0.0          175.0    19.0
# 26     2008.0    20.0   33.0       1.0    0.0          175.0    19.0
# 27     2008.0    20.0   20.0       1.0    1.0          413.0    11.0
# 28     2008.0    20.0   22.0       1.0    1.0          285.0    15.0
# 29     2008.0    20.0    2.0       1.0    0.0           11.0    15.0
# 30     2008.0    18.0    4.0       1.0    0.0          285.0    15.0
# ...       ...     ...    ...       ...    ...            ...     ...
# 52810  2017.0    39.0    4.0       1.0    0.0          130.0    39.0
# 52811  2017.0    39.0    5.0       1.0    0.0          446.0    30.0
# 52812  2017.0    39.0    2.0       1.0    1.0           74.0    21.0
# 52813  2017.0    39.0    1.0       1.0    1.0          285.0    33.0
# 52814  2017.0    39.0    1.0       1.0    0.0          381.0    27.0
# 52815  2017.0    39.0    5.0       1.0    0.0          198.0    32.0
# 52816  2017.0    39.0    7.0       1.0    1.0           78.0    25.0
# 52817  2017.0    39.0    5.0       1.0    0.0          220.0    29.0
# 52818  2017.0    39.0    6.0       1.0    0.0          173.0    39.0
# 52819  2017.0    39.0    5.0       1.0    1.0           49.0    26.0
# 52820  2017.0    39.0    7.0       1.0    1.0          218.0    41.0
# 52822  2017.0    39.0   15.0       1.0    1.0          318.0    37.0
# 52823  2017.0    39.0   16.0       1.0    1.0          388.0    30.0
# 52824  2017.0    39.0   14.0       1.0    1.0          208.0    29.0
# 52825  2017.0    39.0   16.0       1.0    0.0          239.0    32.0
# 52826  2017.0    39.0    8.0       1.0    1.0          458.0    36.0
# 52828  2017.0    39.0    9.0       1.0    0.0           11.0    39.0
# 52829  2017.0    39.0   10.0       1.0    1.0           70.0    35.0
# 52830  2017.0    39.0   10.0       1.0    1.0          116.0    37.0
# 52831  2017.0    39.0   13.0       1.0    0.0           38.0    23.0
# 52833  2017.0    39.0   12.0       1.0    1.0          116.0    37.0
# 52834  2017.0    39.0    9.0       1.0    1.0          288.0    31.0
# 52835  2017.0    39.0   11.0       1.0    0.0           10.0    35.0
# 52836  2017.0    39.0   13.0       1.0    0.0           68.0    23.0
# 52837  2017.0    39.0    9.0       1.0    1.0          236.0    35.0
# 52838  2017.0    39.0    9.0       1.0    0.0           85.0    32.0
# 52839  2017.0    39.0   12.0       1.0    1.0          374.0    32.0
# 52840  2017.0    39.0    8.0       1.0    1.0          368.0    31.0
# 52841  2017.0    39.0   17.0       1.0    1.0           74.0    21.0
# 52842  2017.0    39.0   17.0       1.0    0.0           91.0    35.0
#
#        tipo_ss_  cod_ase_  fec_con_  ini_sin_  tip_cas_  pac_hos_
# 0           0.0      94.0     121.0     162.0       4.0       2.0
# 1           0.0      82.0     122.0     162.0       4.0       2.0
# 2           0.0      82.0     121.0     158.0       4.0       2.0
# 3           0.0      82.0     126.0     165.0       4.0       2.0
# 4           0.0      82.0     122.0     164.0       4.0       2.0
# 5           0.0      88.0     122.0     163.0       4.0       2.0
# 6           0.0      65.0     125.0     160.0       4.0       1.0
# 7           0.0      88.0     121.0     161.0       4.0       2.0
# 8           0.0      88.0     121.0     156.0       4.0       2.0
# 9           0.0      28.0     126.0     166.0       4.0       2.0
# 10          0.0      88.0     122.0     161.0       4.0       2.0
# 11          3.0      82.0     125.0     164.0       4.0       2.0
# 12          0.0     158.0     122.0     163.0       4.0       2.0
# 13          0.0      94.0     128.0     167.0       4.0       2.0
# 14          0.0      94.0     129.0     171.0       4.0       2.0
# 15          0.0      76.0     130.0     170.0       4.0       2.0
# 16          0.0      76.0     130.0     171.0       4.0       2.0
# 17          0.0      82.0     128.0     167.0       4.0       2.0
# 18          0.0      82.0     125.0     165.0       4.0       2.0
# 19          0.0      82.0     125.0     165.0       4.0       2.0
# 20          0.0      82.0     132.0     174.0       4.0       2.0
# 22          0.0      82.0     131.0     166.0       4.0       2.0
# 23          0.0     158.0     131.0     173.0       4.0       2.0
# 24          0.0      94.0      79.0     118.0       4.0       2.0
# 25          0.0      96.0     129.0     169.0       4.0       2.0
# 26          0.0      96.0     130.0     173.0       4.0       2.0
# 27          0.0      94.0     131.0     172.0       4.0       2.0
# 28          0.0      96.0     131.0     173.0       4.0       2.0
# 29          0.0      82.0     121.0     159.0       4.0       2.0
# 30          0.0      78.0     124.0     166.0       4.0       2.0
# ...         ...       ...       ...       ...       ...       ...
# 52810       0.0     119.0    3562.0    3604.0       4.0       2.0
# 52811       0.0      82.0    3558.0    3601.0       4.0       2.0
# 52812       0.0      82.0    3559.0    3603.0       4.0       2.0
# 52813       0.0      78.0    3562.0    3604.0       4.0       2.0
# 52814       0.0      82.0    3555.0    3599.0       4.0       2.0
# 52815       0.0      75.0    3559.0    3599.0       4.0       2.0
# 52816       0.0      75.0    3559.0    3601.0       4.0       2.0
# 52817       0.0      90.0    3555.0    3599.0       4.0       2.0
# 52818       0.0      82.0    3556.0    3600.0       4.0       2.0
# 52819       0.0      82.0    3557.0    3598.0       4.0       2.0
# 52820       0.0      76.0    3554.0    3598.0       4.0       2.0
# 52822       0.0      75.0    3561.0    3602.0       4.0       2.0
# 52823       0.0     103.0    3591.0    3602.0       4.0       2.0
# 52824       0.0     108.0    3562.0    3604.0       4.0       2.0
# 52825       0.0      82.0    3557.0    3600.0       4.0       2.0
# 52826       0.0      82.0    3560.0    3603.0       4.0       2.0
# 52828       0.0     119.0    3562.0    3600.0       4.0       2.0
# 52829       0.0      82.0    3560.0    3599.0       4.0       2.0
# 52830       6.0     128.0    3558.0    3602.0       4.0       2.0
# 52831       0.0      82.0    3558.0    3599.0       4.0       2.0
# 52833       0.0      82.0    3558.0    3600.0       4.0       2.0
# 52834       0.0     108.0    3557.0    3599.0       4.0       2.0
# 52835       0.0      82.0    3557.0    3600.0       4.0       2.0
# 52836       0.0     108.0    3566.0    3600.0       4.0       2.0
# 52837       5.0     155.0    3560.0    3603.0       4.0       2.0
# 52838       0.0      82.0    3556.0    3599.0       4.0       2.0
# 52839       0.0      88.0    3559.0    3603.0       4.0       2.0
# 52840       0.0      82.0    3561.0    3602.0       4.0       2.0
# 52841       0.0     108.0    3557.0    3598.0       4.0       2.0
# 52842       0.0      78.0    3558.0    3600.0       4.0       2.0
#
# [49471 rows x 13 columns]

# %% [markdown]
# # Escalamiento de Datos

# %%
from sklearn.preprocessing import MinMaxScaler 
from matplotlib import pyplot # Librería para hacer gráficas


MinMax_1 = MinMaxScaler(copy=True, feature_range=(0, 1)) # Método MinMax con valores entre 0 y 1

datosEscalados = MinMax_1.fit_transform(datosNuevos) # Transformación de los nuevos datos con una escala MinMax

fig = pyplot.figure(figsize=(12,5)) # Se define el tamaño de la figura en ancho y altura    
    
ax = fig.add_subplot(1, 2, 1)   
ax.scatter(datosNuevos[:,2], datosNuevos[:,5], edgecolors="m")
pyplot.axhline(0, color="blue") # Elegir color de la linea horizontal de referencia
pyplot.xlim(-5, 100) # Definir el rango de valores que desea que aparezca en el gráfico en el eje x
pyplot.ylim(-1, 500) # Definir el rango de valores que desea que aparezca en el gráfico en el eje y
pyplot.title('Datos con Outilers') # Titulo de la gráfica
pyplot.xlabel('Edad') # Etiqueta del eje x
pyplot.ylabel('Barrio') # Etiqueta del eje y

ax = fig.add_subplot(1, 2, 2) 
ax.scatter(datosEscalados[:,2], datosEscalados[:,5], edgecolors="b")
pyplot.axhline(0, color="blue") # Elegir color de la linea horizontal de referencia
pyplot.xlim(-0.5, 1.5) # Definir el rango de valores que desea que aparezca en el gráfico en el eje x
pyplot.ylim(-0.5,  1.5) # Definir el rango de valores que desea que aparezca en el gráfico en el eje y
pyplot.title('Datos con MinMax') # Titulo de la gráfica
pyplot.xlabel('Edad') # Etiqueta del eje x
pyplot.ylabel('Barrio') # Etiqueta del eje y

pyplot.show()

# %% [markdown]
# # Normalización de Datos

# %%
xmax = np.amax(datosNuevos, axis=0) # Se determina los máximos valores de la matriz de datos por columna
xmin = np.amin(datosNuevos, axis=0) # Se determina los minimos valores de la matriz de datos por columna
N,D = datosNuevos.shape # Dimenisones de los datos

metodo_4 = np.zeros( (N,D) ) # Se construye una matriz de ceros de N x D para luego actualizar con los datos nuevos
for d in np.arange(D):
    for n in np.arange(N):
        metodo_4[n][d] = (datosNuevos[n][d] - xmin[d])/(xmax[d] - xmin[d]) # Se aplica el método 4

metodo_4
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# array([[0.        , 0.33333333, 0.1372549 , ..., 0.02407615,        nan,
#         1.        ],
#        [0.        , 0.33333333, 0.64705882, ..., 0.02407615,        nan,
#         1.        ],
#        [0.        , 0.33333333, 0.43137255, ..., 0.02295633,        nan,
#         1.        ],
#        ...,
#        [1.        , 0.74509804, 0.1372549 , ..., 0.98712206,        nan,
#         1.        ],
#        [1.        , 0.74509804, 0.31372549, ..., 0.98600224,        nan,
#         1.        ],
#        [1.        , 0.74509804, 0.31372549, ..., 0.98656215,        nan,
#         1.        ]])

# %% [markdown]
# # Reducción de dimensionalidad

# %%
from sklearn.decomposition import PCA # Cargamos el método PCA

Componentes = PCA(iterated_power='auto', n_components = 13, random_state=None,
                  svd_solver='auto', tol=0.0, whiten=False) # Calcular los valores de las componentes principales


Variables_Principales = Componentes.fit_transform(datosEscalados) 
# Transformarmos las componentes principales a partir de los datos 

Varianza = Componentes.explained_variance_ratio_ # Calculamos la tasa de varianza de las componentes y generamos las 
                                                 # componentes principales   
Varianza
# Out:
# array([2.72947852e-01, 2.45249889e-01, 1.54267960e-01, 7.98226934e-02,
#        7.28544866e-02, 4.71505651e-02, 4.25212074e-02, 3.84523530e-02,
#        3.44507346e-02, 1.22731737e-02, 5.17617700e-06, 3.90774944e-06,
#        0.00000000e+00])

# %%
#Varianza acumulada
fil, col = datosEscalados.shape

ALL_PCA = PCA(col, random_state=None,
                 svd_solver='auto', tol=0.0, whiten=False).fit(datosEscalados)
ALL_Componentes = np.cumsum(ALL_PCA.explained_variance_ratio_)
print(ALL_Componentes)

pyplot.plot(np.arange(len(ALL_Componentes)), ALL_Componentes)
pyplot.xlabel('Componentes Principales')
pyplot.ylabel('Varianza Acumulada')
pyplot.title('PCA con Varianza Acumulada')
pyplot.xlim(0, len(ALL_Componentes))
pyplot.ylim(0, 1)
pyplot.show()
# Out:
# [0.27294785 0.51819774 0.6724657  0.7522884  0.82514288 0.87229345
#  0.91481465 0.95326701 0.98771774 0.99999092 0.99999609 1.
#  1.        ]

# %%
Valores_Singulares = Componentes.singular_values_ # Se calcula los valores singulares por componente principal
Valores_Singulares #Para verificar cuales componentes son las que acumulan la mayor cantidad de información
# Out:
# array([117.30719922, 111.19601799,  88.19068056,  63.43778549,
#         60.60563083,  48.75602335,  46.30070664,  44.02975666,
#         41.67581184,  24.8750101 ,   0.51084528,   0.44386222,
#          0.        ])

# %%
#Se usa el 95% de varianza para explicar el modelo
Nuevas_Componentes = PCA(0.95, random_state=None,
                         svd_solver='auto', tol=0.0, whiten=False) 
Nuevos_Datos = Nuevas_Componentes.fit_transform(datosEscalados) 
print(datosEscalados.shape) # Tamaño de los datos originales
print(Nuevos_Datos.shape)
# Out:
# (49471, 13)
# (49471, 8)

# %%
X_Reconstruido = Nuevas_Componentes.inverse_transform(Nuevos_Datos)#Se reconstruye el modelo a partir de las componentes principales
X_Reconstruido.shape
# Out:
# (49471, 13)

# %%
#Comparación gráfica con PCA y sin PCA
fig = pyplot.figure(figsize=(12,5)) # Se define el tamaño de la figura en ancho y altura 

ax = fig.add_subplot(1, 2, 1) 
ax.scatter(datosEscalados[:,0], datosEscalados[:,1], edgecolors="b")
pyplot.xlabel('Edad') # Etiqueta del eje x
pyplot.ylabel('Barrio') # Etiqueta del eje y
pyplot.title('Sin PCA')

ax = fig.add_subplot(1, 2, 2) 
ax.scatter(X_Reconstruido[:,0], X_Reconstruido[:,1], edgecolors="m")
pyplot.xlabel('Edad') # Etiqueta del eje x
pyplot.ylabel('Barrio') # Etiqueta del eje y
pyplot.title('Datos Reconstruidos a partir de PCA')

pyplot.show()

# %% [markdown]
# # K MEANS

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score # Método de validación silhouette
from sklearn.metrics import calinski_harabasz_score # Método de validación Calinski-Harabasz

from sklearn.utils import check_random_state # Es una librería para definir un generador de números aleatorios a partir de
                                             # de la librería numpy

mantener_valor_aleatorio = check_random_state(1000)
xpts =  Nuevos_Datos[:,0]
ypts =  Nuevos_Datos[:,1]

inercia = []
silhouette_valores = []
ch_valores = []

colors = ['b', 'orange', 'g', 'indigo', 'c', 'm', 'y', 'k', 'Brown', 'ForestGreen']

fig1, axes1 = pyplot.subplots(3, 3, figsize=(8, 8))

for ncenters, ax in enumerate(axes1.reshape(-1), 2):
    Modelo_Kmeans = KMeans(n_clusters = ncenters, init = 'random', n_init = 20, max_iter = 1000, tol = 1e-4,
                      precompute_distances = 'auto', random_state = mantener_valor_aleatorio, algorithm = 'auto')
    Modelo_Kmeans.fit_predict(Nuevos_Datos) # se predice las etiquetas que se asocian a los datos
    Etiquetas = Modelo_Kmeans.labels_ # Calcula las clases o etiquetas
    centros = Modelo_Kmeans.cluster_centers_ # Calcula la matriz de centros
    inercia.append(Modelo_Kmeans.inertia_) # optimiza el punto de inercia de acuerdo al número de clusters
    silhouette_valores.append(silhouette_score(Nuevos_Datos, Etiquetas)) # Se aplica la métrica Silhouette
    ch_valores.append(calinski_harabasz_score(Nuevos_Datos, Etiquetas)) # Se aplica la métrica Calinski-Harabasz
    
    for j in range(ncenters):
        ax.plot(xpts[Etiquetas == j],
                ypts[Etiquetas == j], '.', color=colors[j])
        
    print("Para ", ncenters, " Clusters: ")   
    for i in range (len(np.unique(Etiquetas))):
        
        print("El total de datos de la clase ", i, " son: ", len(Etiquetas[Etiquetas==i]))
    

    for pt in centros:
        ax.plot(pt[0], pt[1], 'rs')
    
    ax.set_title('clusters = {0}'.format(ncenters))
    ax.axis('off') 

fig1.tight_layout()
pyplot.show()

fig2, ax2 = pyplot.subplots()
ax2.plot(np.r_[2:11], inercia, marker = 'o')
ax2.set_xlabel("Número de Clusters")
ax2.set_ylabel("Inercia")
pyplot.show()

fig3, ax3 = pyplot.subplots()
ax3.plot(np.r_[2:11], silhouette_valores, marker = 'o')
ax3.set_xlabel("Número de Clusters")
ax3.set_ylabel("Valor de silhouette")
pyplot.show()

fig3, ax3 = pyplot.subplots()
ax3.plot(np.r_[2:11], ch_valores, marker = 'o')
ax3.set_xlabel("Número de Clusters")
ax3.set_ylabel("Valor de índice Calinski-Harabasz")
pyplot.show()

##El de 2 o el de 4. Serian los elegidos.
# Out:
# Para  2  Clusters:
# El total de datos de la clase  0  son:  25222
# El total de datos de la clase  1  son:  24249
# Para  3  Clusters:
# El total de datos de la clase  0  son:  13565
# El total de datos de la clase  1  son:  11657
# El total de datos de la clase  2  son:  24249
# Para  4  Clusters:
# El total de datos de la clase  0  son:  11657
# El total de datos de la clase  1  son:  11245
# El total de datos de la clase  2  son:  13004
# El total de datos de la clase  3  son:  13565
# Para  5  Clusters:
# El total de datos de la clase  0  son:  10302
# El total de datos de la clase  1  son:  6086
# El total de datos de la clase  2  son:  11477
# El total de datos de la clase  3  son:  10639
# El total de datos de la clase  4  son:  10967
# Para  6  Clusters:
# El total de datos de la clase  0  son:  4928
# El total de datos de la clase  1  son:  8993
# El total de datos de la clase  2  son:  11149
# El total de datos de la clase  3  son:  5080
# El total de datos de la clase  4  son:  8718
# El total de datos de la clase  5  son:  10603
# Para  7  Clusters:
# El total de datos de la clase  0  son:  4728
# El total de datos de la clase  1  son:  10659
# El total de datos de la clase  2  son:  8776
# El total de datos de la clase  3  son:  10140
# El total de datos de la clase  4  son:  8496
# El total de datos de la clase  5  son:  4841
# El total de datos de la clase  6  son:  1831
# Para  8  Clusters:
# El total de datos de la clase  0  son:  2858
# El total de datos de la clase  1  son:  3155
# El total de datos de la clase  2  son:  2690
# El total de datos de la clase  3  son:  3230
# El total de datos de la clase  4  son:  9832
# El total de datos de la clase  5  son:  8497
# El total de datos de la clase  6  son:  10442
# El total de datos de la clase  7  son:  8767
# Para  9  Clusters:
# El total de datos de la clase  0  son:  7399
# El total de datos de la clase  1  son:  2680
# El total de datos de la clase  2  son:  5370
# El total de datos de la clase  3  son:  8495
# El total de datos de la clase  4  son:  2475
# El total de datos de la clase  5  son:  7298
# El total de datos de la clase  6  son:  2691
# El total de datos de la clase  7  son:  3227
# El total de datos de la clase  8  son:  9836
# Para  10  Clusters:
# El total de datos de la clase  0  son:  2562
# El total de datos de la clase  1  son:  2582
# El total de datos de la clase  2  son:  2536
# El total de datos de la clase  3  son:  8475
# El total de datos de la clase  4  son:  10764
# El total de datos de la clase  5  son:  4879
# El total de datos de la clase  6  son:  5828
# El total de datos de la clase  7  son:  7776
# El total de datos de la clase  8  son:  2375
# El total de datos de la clase  9  son:  1694

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN # Se aplica el algoritmo de clustering DBSCAN
from sklearn.datasets import make_moons # base de datos de las lunas 
import mglearn


epss = [0.1,0.3,0.5,0.7,0.9]
mins = [10,30,50,80,100]

for eps in epss:
    for mi in mins:
        print ("Se realiza la prueba con eps:", eps)
        print ("y con minimas muestras:", mi)
        Modelo_DBSCAN_Basico = DBSCAN(eps = eps, metric = 'euclidean', algorithm = 'auto', leaf_size = 10, min_samples = mi) 
        Modelo_DBSCAN_Basico.fit_predict(Nuevos_Datos)
        Etiquetas = Modelo_DBSCAN_Basico.labels_ # Calcula las clases o etiquetas con ruido
        centros = Modelo_DBSCAN_Basico.components_ # Calcula la matriz de centros nucleares
        core_samples_mask = np.zeros_like(Etiquetas, dtype=bool)
        core_samples_mask[Modelo_DBSCAN_Basico.core_sample_indices_] = True     
        n_clusters_ = len(set(Etiquetas)) - (1 if -1 in Etiquetas else 0)
        n_ruido_ = list(Etiquetas).count(-1)
        Clases_Sin_Ruido = Modelo_DBSCAN_Basico.labels_ # Calcula las clases o etiquetas sin ruido

        unique_labels = set(Clases_Sin_Ruido)
        colors = [pyplot.cm.Spectral(each)
                  for each in np.linspace(0, 1, len(unique_labels))]

        print('Número estimado de datos con ruido: %d' % n_ruido_)

        for k, col in zip(unique_labels, colors):
            if k == -1:
                # Los puntos negros significan datos con ruido y que no pudieron ser agrupados
                col = [0, 0, 0, 1]

            class_member_mask = (Clases_Sin_Ruido == k)

            xy = Nuevos_Datos[class_member_mask & core_samples_mask]
            pyplot.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                     markeredgecolor='k', markersize=14)

            xy = Nuevos_Datos[class_member_mask & ~core_samples_mask]
            pyplot.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                     markeredgecolor='k', markersize=6)

        #print("Para ", ncenters, " Clusters: ")   
        for i in range (len(np.unique(Etiquetas)) -1):
            print("El total de datos de la clase ", i, " son: ", len(Etiquetas[Etiquetas==i]))

        pyplot.title('Número estimado de clusters: %d' % n_clusters_)
        pyplot.show()
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Se realiza la prueba con eps: 0.1
# y con minimas muestras: 10
# Número estimado de datos con ruido: 30370
# El total de datos de la clase  0  son:  1090
# El total de datos de la clase  1  son:  855
# El total de datos de la clase  2  son:  22
# El total de datos de la clase  3  son:  18
# El total de datos de la clase  4  son:  10
# El total de datos de la clase  5  son:  17
# El total de datos de la clase  6  son:  10
# El total de datos de la clase  7  son:  10
# El total de datos de la clase  8  son:  12
# El total de datos de la clase  9  son:  10
# El total de datos de la clase  10  son:  21
# El total de datos de la clase  11  son:  40
# El total de datos de la clase  12  son:  23
# El total de datos de la clase  13  son:  26
# El total de datos de la clase  14  son:  10
# El total de datos de la clase  15  son:  9
# El total de datos de la clase  16  son:  23
# El total de datos de la clase  17  son:  7
# El total de datos de la clase  18  son:  8
# El total de datos de la clase  19  son:  295
# El total de datos de la clase  20  son:  14
# El total de datos de la clase  21  son:  422
# El total de datos de la clase  22  son:  19
# El total de datos de la clase  23  son:  15
# El total de datos de la clase  24  son:  17
# El total de datos de la clase  25  son:  13
# El total de datos de la clase  26  son:  21
# El total de datos de la clase  27  son:  17
# El total de datos de la clase  28  son:  10
# El total de datos de la clase  29  son:  41
# El total de datos de la clase  30  son:  17
# El total de datos de la clase  31  son:  14
# El total de datos de la clase  32  son:  19
# El total de datos de la clase  33  son:  41
# El total de datos de la clase  34  son:  6
# El total de datos de la clase  35  son:  9
# El total de datos de la clase  36  son:  15
# El total de datos de la clase  37  son:  14
# El total de datos de la clase  38  son:  40
# El total de datos de la clase  39  son:  11
# El total de datos de la clase  40  son:  10
# El total de datos de la clase  41  son:  10
# El total de datos de la clase  42  son:  10
# El total de datos de la clase  43  son:  48
# El total de datos de la clase  44  son:  27
# El total de datos de la clase  45  son:  10
# El total de datos de la clase  46  son:  20
# El total de datos de la clase  47  son:  12
# El total de datos de la clase  48  son:  491
# El total de datos de la clase  49  son:  475
# El total de datos de la clase  50  son:  14
# El total de datos de la clase  51  son:  13
# El total de datos de la clase  52  son:  26
# El total de datos de la clase  53  son:  15
# El total de datos de la clase  54  son:  20
# El total de datos de la clase  55  son:  11
# El total de datos de la clase  56  son:  27
# El total de datos de la clase  57  son:  10
# El total de datos de la clase  58  son:  10
# El total de datos de la clase  59  son:  8
# El total de datos de la clase  60  son:  7
# El total de datos de la clase  61  son:  10
# El total de datos de la clase  62  son:  10
# El total de datos de la clase  63  son:  1247
# El total de datos de la clase  64  son:  1496
# El total de datos de la clase  65  son:  28
# El total de datos de la clase  66  son:  14
# El total de datos de la clase  67  son:  8
# El total de datos de la clase  68  son:  10
# El total de datos de la clase  69  son:  17
# El total de datos de la clase  70  son:  7
# El total de datos de la clase  71  son:  9
# El total de datos de la clase  72  son:  7
# El total de datos de la clase  73  son:  11
# El total de datos de la clase  74  son:  10
# El total de datos de la clase  75  son:  68
# El total de datos de la clase  76  son:  25
# El total de datos de la clase  77  son:  658
# El total de datos de la clase  78  son:  887
# El total de datos de la clase  79  son:  14
# El total de datos de la clase  80  son:  15
# El total de datos de la clase  81  son:  25
# El total de datos de la clase  82  son:  15
# El total de datos de la clase  83  son:  30
# El total de datos de la clase  84  son:  13
# El total de datos de la clase  85  son:  34
# El total de datos de la clase  86  son:  37
# El total de datos de la clase  87  son:  29
# El total de datos de la clase  88  son:  11
# El total de datos de la clase  89  son:  15
# El total de datos de la clase  90  son:  19
# El total de datos de la clase  91  son:  127
# El total de datos de la clase  92  son:  165
# El total de datos de la clase  93  son:  490
# El total de datos de la clase  94  son:  10
# El total de datos de la clase  95  son:  10
# El total de datos de la clase  96  son:  31
# El total de datos de la clase  97  son:  15
# El total de datos de la clase  98  son:  10
# El total de datos de la clase  99  son:  17
# El total de datos de la clase  100  son:  39
# El total de datos de la clase  101  son:  20
# El total de datos de la clase  102  son:  8
# El total de datos de la clase  103  son:  20
# El total de datos de la clase  104  son:  9
# El total de datos de la clase  105  son:  9
# El total de datos de la clase  106  son:  16
# El total de datos de la clase  107  son:  27
# El total de datos de la clase  108  son:  20
# El total de datos de la clase  109  son:  12
# El total de datos de la clase  110  son:  10
# El total de datos de la clase  111  son:  13
# El total de datos de la clase  112  son:  9
# El total de datos de la clase  113  son:  1017
# El total de datos de la clase  114  son:  15
# El total de datos de la clase  115  son:  70
# El total de datos de la clase  116  son:  848
# El total de datos de la clase  117  son:  55
# El total de datos de la clase  118  son:  15
# El total de datos de la clase  119  son:  5
# El total de datos de la clase  120  son:  8
# El total de datos de la clase  121  son:  26
# El total de datos de la clase  122  son:  17
# El total de datos de la clase  123  son:  17
# El total de datos de la clase  124  son:  18
# El total de datos de la clase  125  son:  12
# El total de datos de la clase  126  son:  19
# El total de datos de la clase  127  son:  12
# El total de datos de la clase  128  son:  24
# El total de datos de la clase  129  son:  17
# El total de datos de la clase  130  son:  17
# El total de datos de la clase  131  son:  10
# El total de datos de la clase  132  son:  9
# El total de datos de la clase  133  son:  20
# El total de datos de la clase  134  son:  17
# El total de datos de la clase  135  son:  30
# El total de datos de la clase  136  son:  26
# El total de datos de la clase  137  son:  13
# El total de datos de la clase  138  son:  8
# El total de datos de la clase  139  son:  11
# El total de datos de la clase  140  son:  12
# El total de datos de la clase  141  son:  27
# El total de datos de la clase  142  son:  14
# El total de datos de la clase  143  son:  11
# El total de datos de la clase  144  son:  10
# El total de datos de la clase  145  son:  10
# El total de datos de la clase  146  son:  14
# El total de datos de la clase  147  son:  8
# El total de datos de la clase  148  son:  947
# El total de datos de la clase  149  son:  948
# El total de datos de la clase  150  son:  117
# El total de datos de la clase  151  son:  37
# El total de datos de la clase  152  son:  116
# El total de datos de la clase  153  son:  18
# El total de datos de la clase  154  son:  11
# El total de datos de la clase  155  son:  11
# El total de datos de la clase  156  son:  12
# El total de datos de la clase  157  son:  29
# El total de datos de la clase  158  son:  23
# El total de datos de la clase  159  son:  20
# El total de datos de la clase  160  son:  63
# El total de datos de la clase  161  son:  24
# El total de datos de la clase  162  son:  50
# El total de datos de la clase  163  son:  41
# El total de datos de la clase  164  son:  18
# El total de datos de la clase  165  son:  17
# El total de datos de la clase  166  son:  13
# El total de datos de la clase  167  son:  9
# El total de datos de la clase  168  son:  8
# El total de datos de la clase  169  son:  9
# El total de datos de la clase  170  son:  10
# El total de datos de la clase  171  son:  800
# El total de datos de la clase  172  son:  981
# El total de datos de la clase  173  son:  16
# El total de datos de la clase  174  son:  23
# El total de datos de la clase  175  son:  22
# El total de datos de la clase  176  son:  24
# El total de datos de la clase  177  son:  15
# El total de datos de la clase  178  son:  17
# El total de datos de la clase  179  son:  17
# El total de datos de la clase  180  son:  17
# El total de datos de la clase  181  son:  25
# El total de datos de la clase  182  son:  18
# El total de datos de la clase  183  son:  10
# El total de datos de la clase  184  son:  8
# El total de datos de la clase  185  son:  10
# El total de datos de la clase  186  son:  15
# El total de datos de la clase  187  son:  15
# El total de datos de la clase  188  son:  10
# El total de datos de la clase  189  son:  21
# El total de datos de la clase  190  son:  690
# El total de datos de la clase  191  son:  719
# El total de datos de la clase  192  son:  6
# El total de datos de la clase  193  son:  18
# El total de datos de la clase  194  son:  18
# El total de datos de la clase  195  son:  15
# El total de datos de la clase  196  son:  12
# El total de datos de la clase  197  son:  11
# El total de datos de la clase  198  son:  15
# El total de datos de la clase  199  son:  18
# El total de datos de la clase  200  son:  7
# El total de datos de la clase  201  son:  13
# El total de datos de la clase  202  son:  10
# El total de datos de la clase  203  son:  8
# El total de datos de la clase  204  son:  13
# El total de datos de la clase  205  son:  8
# El total de datos de la clase  206  son:  12
# Se realiza la prueba con eps: 0.1
# y con minimas muestras: 30
# Número estimado de datos con ruido: 46232
# El total de datos de la clase  0  son:  188
# El total de datos de la clase  1  son:  206
# El total de datos de la clase  2  son:  61
# El total de datos de la clase  3  son:  39
# El total de datos de la clase  4  son:  32
# El total de datos de la clase  5  son:  90
# El total de datos de la clase  6  son:  27
# El total de datos de la clase  7  son:  25
# El total de datos de la clase  8  son:  25
# El total de datos de la clase  9  son:  374
# El total de datos de la clase  10  son:  331
# El total de datos de la clase  11  son:  23
# El total de datos de la clase  12  son:  175
# El total de datos de la clase  13  son:  78
# El total de datos de la clase  14  son:  141
# El total de datos de la clase  15  son:  166
# El total de datos de la clase  16  son:  187
# El total de datos de la clase  17  son:  164
# El total de datos de la clase  18  son:  47
# El total de datos de la clase  19  son:  92
# El total de datos de la clase  20  son:  118
# El total de datos de la clase  21  son:  30
# El total de datos de la clase  22  son:  55
# El total de datos de la clase  23  son:  60
# El total de datos de la clase  24  son:  53
# El total de datos de la clase  25  son:  31
# El total de datos de la clase  26  son:  29
# El total de datos de la clase  27  son:  32
# El total de datos de la clase  28  son:  52
# El total de datos de la clase  29  son:  90
# El total de datos de la clase  30  son:  35
# El total de datos de la clase  31  son:  31
# El total de datos de la clase  32  son:  41
# El total de datos de la clase  33  son:  80
# El total de datos de la clase  34  son:  31
# Se realiza la prueba con eps: 0.1
# y con minimas muestras: 50
# Número estimado de datos con ruido: 48942
# El total de datos de la clase  0  son:  177
# El total de datos de la clase  1  son:  113
# El total de datos de la clase  2  son:  50
# El total de datos de la clase  3  son:  103
# El total de datos de la clase  4  son:  86
# Se realiza la prueba con eps: 0.1
# y con minimas muestras: 80
# Número estimado de datos con ruido: 49471
# Se realiza la prueba con eps: 0.1
# y con minimas muestras: 100
# Número estimado de datos con ruido: 49471
# Se realiza la prueba con eps: 0.3
# y con minimas muestras: 10
# Número estimado de datos con ruido: 972
# El total de datos de la clase  0  son:  19445
# El total de datos de la clase  1  son:  18683
# El total de datos de la clase  2  son:  679
# El total de datos de la clase  3  son:  723
# El total de datos de la clase  4  son:  4314
# El total de datos de la clase  5  son:  4229
# El total de datos de la clase  6  son:  129
# El total de datos de la clase  7  son:  123
# El total de datos de la clase  8  son:  45
# El total de datos de la clase  9  son:  36
# El total de datos de la clase  10  son:  59
# El total de datos de la clase  11  son:  16
# El total de datos de la clase  12  son:  10
# El total de datos de la clase  13  son:  8
# Se realiza la prueba con eps: 0.3
# y con minimas muestras: 30
# Número estimado de datos con ruido: 3014
# El total de datos de la clase  0  son:  17787
# El total de datos de la clase  1  son:  17048
# El total de datos de la clase  2  son:  1092
# El total de datos de la clase  3  son:  1065
# El total de datos de la clase  4  son:  2595
# El total de datos de la clase  5  son:  3062
# El total de datos de la clase  6  son:  164
# El total de datos de la clase  7  son:  550
# El total de datos de la clase  8  son:  593
# El total de datos de la clase  9  son:  43
# El total de datos de la clase  10  son:  1062
# El total de datos de la clase  11  son:  1063
# El total de datos de la clase  12  son:  333
# Se realiza la prueba con eps: 0.3
# y con minimas muestras: 50
# Número estimado de datos con ruido: 4844
# El total de datos de la clase  0  son:  17736
# El total de datos de la clase  1  son:  16986
# El total de datos de la clase  2  son:  897
# El total de datos de la clase  3  son:  892
# El total de datos de la clase  4  son:  2558
# El total de datos de la clase  5  son:  1042
# El total de datos de la clase  6  son:  69
# El total de datos de la clase  7  son:  1291
# El total de datos de la clase  8  son:  186
# El total de datos de la clase  9  son:  222
# El total de datos de la clase  10  son:  1053
# El total de datos de la clase  11  son:  1049
# El total de datos de la clase  12  son:  42
# El total de datos de la clase  13  son:  293
# El total de datos de la clase  14  son:  311
# Se realiza la prueba con eps: 0.3
# y con minimas muestras: 80
# Número estimado de datos con ruido: 8088
# El total de datos de la clase  0  son:  17634
# El total de datos de la clase  1  son:  16893
# El total de datos de la clase  2  son:  84
# El total de datos de la clase  3  son:  772
# El total de datos de la clase  4  son:  865
# El total de datos de la clase  5  son:  324
# El total de datos de la clase  6  son:  1202
# El total de datos de la clase  7  son:  1108
# El total de datos de la clase  8  son:  80
# El total de datos de la clase  9  son:  1031
# El total de datos de la clase  10  son:  1013
# El total de datos de la clase  11  son:  181
# El total de datos de la clase  12  son:  135
# El total de datos de la clase  13  son:  61
# Se realiza la prueba con eps: 0.3
# y con minimas muestras: 100
# Número estimado de datos con ruido: 9486
# El total de datos de la clase  0  son:  17554
# El total de datos de la clase  1  son:  16815
# El total de datos de la clase  2  son:  597
# El total de datos de la clase  3  son:  736
# El total de datos de la clase  4  son:  195
# El total de datos de la clase  5  son:  1067
# El total de datos de la clase  6  son:  997
# El total de datos de la clase  7  son:  1022
# El total de datos de la clase  8  son:  1002
# Se realiza la prueba con eps: 0.5
# y con minimas muestras: 10
# Número estimado de datos con ruido: 8
# El total de datos de la clase  0  son:  24038
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1119
# El total de datos de la clase  3  son:  1178
# Se realiza la prueba con eps: 0.5
# y con minimas muestras: 30
# Número estimado de datos con ruido: 160
# El total de datos de la clase  0  son:  24033
# El total de datos de la clase  1  son:  23126
# El total de datos de la clase  2  son:  863
# El total de datos de la clase  3  son:  906
# El total de datos de la clase  4  son:  190
# El total de datos de la clase  5  son:  162
# El total de datos de la clase  6  son:  31
# Se realiza la prueba con eps: 0.5
# y con minimas muestras: 50
# Número estimado de datos con ruido: 473
# El total de datos de la clase  0  son:  24026
# El total de datos de la clase  1  son:  23120
# El total de datos de la clase  2  son:  862
# El total de datos de la clase  3  son:  897
# El total de datos de la clase  4  son:  53
# El total de datos de la clase  5  son:  40
# Se realiza la prueba con eps: 0.5
# y con minimas muestras: 80
# Número estimado de datos con ruido: 766
# El total de datos de la clase  0  son:  24016
# El total de datos de la clase  1  son:  23115
# El total de datos de la clase  2  son:  754
# El total de datos de la clase  3  son:  820
# Se realiza la prueba con eps: 0.5
# y con minimas muestras: 100
# Número estimado de datos con ruido: 803
# El total de datos de la clase  0  son:  24008
# El total de datos de la clase  1  son:  23110
# El total de datos de la clase  2  son:  805
# El total de datos de la clase  3  son:  745
# Se realiza la prueba con eps: 0.7
# y con minimas muestras: 10
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.7
# y con minimas muestras: 30
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.7
# y con minimas muestras: 50
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.7
# y con minimas muestras: 80
# Número estimado de datos con ruido: 15
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1108
# El total de datos de la clase  3  son:  1179
# Se realiza la prueba con eps: 0.7
# y con minimas muestras: 100
# Número estimado de datos con ruido: 45
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1087
# El total de datos de la clase  3  son:  1170
# Se realiza la prueba con eps: 0.9
# y con minimas muestras: 10
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.9
# y con minimas muestras: 30
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.9
# y con minimas muestras: 50
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.9
# y con minimas muestras: 80
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121
# Se realiza la prueba con eps: 0.9
# y con minimas muestras: 100
# Número estimado de datos con ruido: 0
# El total de datos de la clase  0  son:  24041
# El total de datos de la clase  1  son:  23128
# El total de datos de la clase  2  son:  1121

# %% [markdown]
# # GK-Means

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import check_random_state # Es una librería para definir un generador de números aleatorios a partir de
                                             # de la librería numpy
from skcmeans.algorithms import Probabilistic, GustafsonKesselMixin # Algoritmo GK probabilístico

from cvi import * # Indices de validación interna

# cvi es una librería desarrollada por 99991
# ir a la url: https://github.com/99991/FuzzyClustering/blob/master/cvi.py
# pip install git+git://github.com/bm424/scikit-cmeans.git@master


class GKProbabilistic(Probabilistic, GustafsonKesselMixin):
    pass
xpts =  Nuevos_Datos[:,0]
ypts =  Nuevos_Datos[:,1]

fig1, axes1 = plt.subplots(2, 2, figsize=(8, 8))
resultados = []
cs = np.arange(2, 6) # Rango de número mínimo y máximo de clusters
mantener_valor_aleatorio = check_random_state(1000)

colors = ['b', 'orange', 'g', 'r', 'c', 'm', 'y', 'k', 'Brown', 'ForestGreen']

for ncenters, ax in enumerate(axes1.reshape(-1), 2):
    modelo_GK = GKProbabilistic(n_clusters = ncenters, n_init = 20, max_iter = 300, 
                                tol=1e-3, verbosity = 0, random_state = mantener_valor_aleatorio, eps = 1e-18)
    Ajuste = modelo_GK.fit(Nuevos_Datos)
    U = Ajuste.calculate_memberships(Nuevos_Datos)
    centros = Ajuste.calculate_centers(Nuevos_Datos)
    cluster_membership = np.argmax(U.T, axis=0)
    
    for j in range(ncenters):
        ax.plot(xpts[cluster_membership == j],
                ypts[cluster_membership == j], '.', color=colors[j])
    
    for pt in centros:
        ax.plot(pt[0], pt[1], 'rs')
        
    ax.set_title('clusters = {0}'.format(ncenters))
    ax.axis('off')
    
    resultados.append([])
    for method in methods:
        resultado = method(Nuevos_Datos, U.T, centros, m = 2)
        resultados[-1].append(resultado)

plt.tight_layout()
plt.show()

resultados = np.array(resultados)

ny = 4
nx = 2

for i, method in enumerate(methods):
    plt.subplot(ny, nx, 1 + i)
    column = resultados[:, i]
    plt.plot(cs, column)
    if targets[i] == "min":
        ncenters = cs[np.argmin(column)]
    else:
        ncenters = cs[np.argmax(column)]
    plt.title("%s, %s es de %d"%(method.__name__, targets[i], ncenters))   
    plt.plot([ncenters, ncenters],[np.min(column), np.max(column)])

plt.tight_layout()
plt.show()

# %%
ncenters = 2

modelo_GK = GKProbabilistic(n_clusters = ncenters, n_init = 20, max_iter = 300, 
                                tol=1e-3, verbosity = 0, random_state = mantener_valor_aleatorio, eps = 1e-18)
Ajuste = modelo_GK.fit(Nuevos_Datos)

U = Ajuste.calculate_memberships(Nuevos_Datos)

Target = np.argmax(U.T, axis=0)

print(len(Target))

Datos_para_clasificar = Nuevos_Datos

Clases = Target

print("Para ", ncenters, " Clusters: ")   
for i in range (len(np.unique(Clases))):       
    print("El total de datos de la clase ", i, " son: ", len(Clases[Clases==i]))
# Out:
# 49471
# Para  2  Clusters:
# El total de datos de la clase  0  son:  2856
# El total de datos de la clase  1  son:  46615
